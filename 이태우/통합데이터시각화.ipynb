# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 폰트 설정
# 사용자 운영체제 확인
import os
os.name

# 운영체제별 한글 폰트 설정
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

# 글씨 선명하게 출력하기 
# %config InlineBackend.figure_format = 'retina'

# %%
main = pd.read_csv("통합비교분석데이터.csv")

# %%
main
# Out:
#      시군구  터널수      총길이  2018_평균 강수량  2019_평균 강수량  2020_평균 강수량  2020년_산사태_발생건수  \
# 0    용인시   51  30770.5   206.933333   120.200000   401.000000            25.0
# 1    성남시   49  37405.3   212.500000   155.333333   365.500000             0.0
# 2   남양주시   45  34195.7   211.633333   187.333333   393.700000             1.0
# 3    광주시   40  30337.0   210.700000   173.533333   358.666667             0.0
# 4    여주시   23  17530.0   209.566667   131.700000   382.033333             2.0
# 5    가평군   20  17174.9   221.733333   174.466667   382.500000            19.0
# 6    안성시   19  14905.0   193.566667   118.533333   381.900000            94.0
# 7    의왕시   16   8270.0   190.800000   149.400000   305.733333             0.0
# 8    양주시   16  21673.0   239.366667   154.300000   384.833333             0.0
# 9    파주시   16   7107.0   221.833333   161.233333   335.366667             2.0
# 10   양평군   16  11592.0   197.166667   154.866667   303.366667            16.0
# ...

# %%
main.corr()
# Out:
#                      터널수       총길이  2018_평균 강수량  2019_평균 강수량  2020_평균 강수량  \
# 터널수             1.000000  0.941823     0.016041     0.024354     0.142209
# 총길이             0.941823  1.000000     0.042527     0.119542     0.226256
# 2018_평균 강수량     0.016041  0.042527     1.000000     0.215422     0.303026
# 2019_평균 강수량     0.024354  0.119542     0.215422     1.000000     0.211603
# 2020_평균 강수량     0.142209  0.226256     0.303026     0.211603     1.000000
# 2020년_산사태_발생건수  0.107265  0.085618     0.021803    -0.312428     0.214879
# 2020년_산사태피해면적   0.097009  0.084937    -0.001209    -0.305527     0.184807
#
#                 2020년_산사태_발생건수  2020년_산사태피해면적
# 터널수                   0.107265       0.097009
# 총길이                   0.085618       0.084937
# 2018_평균 강수량           0.021803      -0.001209
# 2019_평균 강수량          -0.312428      -0.305527
# 2020_평균 강수량           0.214879       0.184807
# 2020년_산사태_발생건수        1.000000       0.993690
# 2020년_산사태피해면적         0.993690       1.000000

# %%
sns.heatmap(main.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(25,15))
plt.plot(main.시군구, main.터널수,"o--")
plt.plot(main.시군구, main["2020년_산사태_발생건수"],"D:")
plt.title('터널 수와 산사태', fontsize=25)
plt.ylabel('터널 수와 산사태 발생건수', fontsize=18)
plt.xlabel('시도군', fontsize=18)
plt.legend(fontsize=13)
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
